# %%
import pandas as pd

# %%
match= pd.read_csv("matches.csv")

# %%
match.head(5)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
city_updated= match['city'].replace({'Bangalore':'Bengaluru','Navi Mumbai':'Mumbai'})
city_updated
# Out:
# 0        Bengaluru
# 1       Chandigarh
# 2            Delhi
# 3           Mumbai
# 4          Kolkata
#            ...
# 1090     Hyderabad
# 1091     Ahmedabad
# 1092     Ahmedabad
# 1093       Chennai
# 1094       Chennai
# Name: city, Length: 1095, dtype: object

# %%
venue_updated=match['venue'].replace({'M Chinnaswamy Stadium':'M Chinnaswamy Stadium, Bengaluru',
                                      'M.Chinnaswamy Stadium':'M Chinnaswamy Stadium, Bengaluru',
                                      'Punjab Cricket Association IS Bindra Stadium':'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh',
                                      'Punjab Cricket Association IS Bindra Stadium, Mohali':'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh',
                                      'Punjab Cricket Association Stadium, Mohali':'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh',
                                      'MA Chidambaram Stadium':'MA Chidambaram Stadium, Chepauk, Chennai',
                                      'MA Chidambaram Stadium, Chepauk':'MA Chidambaram Stadium, Chepauk, Chennai',
                                      'Arun Jaitley Stadium':'Arun Jaitley Stadium, Delhi',
                                      'Himachal Pradesh Cricket Association Stadium':'Himachal Pradesh Cricket Association Stadium, Dharamsala',
                                      'Rajiv Gandhi International Stadium':'Rajiv Gandhi International Stadium, Uppal, Hyderabad',
                                      'Rajiv Gandhi International Stadium, Uppal':'Rajiv Gandhi International Stadium, Uppal, Hyderabad',
                                      'Sawai Mansingh Stadium':'Sawai Mansingh Stadium, Jaipur',
                                      'Eden Gardens':'Eden Gardens, Kolkata',
                                      'Brabourne Stadium':'Brabourne Stadium, Mumbai',
                                      'Dr DY Patil Sports Academy':'Dr DY Patil Sports Academy, Mumbai',
                                      'Wankhede Stadium':'Wankhede Stadium, Mumbai',
                                      'Maharashtra Cricket Association Stadium':'Maharashtra Cricket Association Stadium, Pune',
                                      'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium':'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam',
                                      })
venue_updated
# Out:
# 0                        M Chinnaswamy Stadium, Bengaluru
# 1       Punjab Cricket Association IS Bindra Stadium, ...
# 2                                        Feroz Shah Kotla
# 3                                Wankhede Stadium, Mumbai
# 4                                   Eden Gardens, Kolkata
#                               ...
# 1090    Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                     Narendra Modi Stadium, Ahmedabad
# 1092                     Narendra Modi Stadium, Ahmedabad
# 1093             MA Chidambaram Stadium, Chepauk, Chennai
# 1094             MA Chidambaram Stadium, Chepauk, Chennai
# Name: venue, Length: 1095, dtype: object

# %%
match['venue']=venue_updated
match
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
match['city']=city_updated
match
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bengaluru  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
city_and_venue = match.groupby(['city', 'venue']).size().reset_index(name='count')
final_city_and_venue=city_and_venue.sort_values(by='count', ascending=False)
final_city_and_venue
# Out:
#               city                                              venue  count
# 30          Mumbai                           Wankhede Stadium, Mumbai    118
# 4        Bengaluru                   M Chinnaswamy Stadium, Bengaluru     94
# 25         Kolkata                              Eden Gardens, Kolkata     93
# 9          Chennai           MA Chidambaram Stadium, Chepauk, Chennai     85
# 18       Hyderabad  Rajiv Gandhi International Stadium, Uppal, Hyd...     77
# 8       Chandigarh  Punjab Cricket Association IS Bindra Stadium, ...     61
# 12           Delhi                                   Feroz Shah Kotla     60
# 20          Jaipur                     Sawai Mansingh Stadium, Jaipur     57
# 29          Mumbai                 Dr DY Patil Sports Academy, Mumbai     37
# 33            Pune      Maharashtra Cricket Association Stadium, Pune     35
# 11           Delhi                        Arun Jaitley Stadium, Delhi     30
# ...

# %%
result_types = match['result'].value_counts()
result_types
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
average_margin = match['result_margin'].mean()
print(f"\nAverage Result Margin: {average_margin:.2f}")
# Out:
# Average Result Margin: 17.26

# %%
final_city_and_venue.head(10) #Top 10 Venues
# Out:
#           city                                              venue  count
# 30      Mumbai                           Wankhede Stadium, Mumbai    118
# 4    Bengaluru                   M Chinnaswamy Stadium, Bengaluru     94
# 25     Kolkata                              Eden Gardens, Kolkata     93
# 9      Chennai           MA Chidambaram Stadium, Chepauk, Chennai     85
# 18   Hyderabad  Rajiv Gandhi International Stadium, Uppal, Hyd...     77
# 8   Chandigarh  Punjab Cricket Association IS Bindra Stadium, ...     61
# 12       Delhi                                   Feroz Shah Kotla     60
# 20      Jaipur                     Sawai Mansingh Stadium, Jaipur     57
# 29      Mumbai                 Dr DY Patil Sports Academy, Mumbai     37
# 33        Pune      Maharashtra Cricket Association Stadium, Pune     35

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Bar chart that represent the number of matches in top 10 venue

plt.figure(figsize=(10, 10))
ax=sns.barplot(x='count', y='venue', data=final_city_and_venue.head(10), color='blue') #also use palatte='plasma'
ax.bar_label(ax.containers[0], fmt='%d')

plt.title("total Matchs held in Each state",fontsize =14)
plt.ylabel("top venues")
plt.xlabel("number of matches")
plt.show()
