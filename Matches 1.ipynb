# %%
import pandas as pd

# %%
#Creating data¶
#There are two core objects in pandas: the DataFrame and the Series.
#DataFrame
#A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. 
#Each entry corresponds to a row (or record) and a column.

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
#DataFrame entries are not limited to integers. For instance, here's a DataFrame whose values are strings:
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
#Series
#A Series, by contrast, is a sequence of data values. 
#If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list:

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
Matches = pd.read_csv("matches.csv")

# %%
Matches.shape
# Out:
# (1095, 20)

# %%
Matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
Matches = pd.read_csv("matches.csv", index_col=0)
Matches.head()
# Out:
#          season        city        date match_type player_of_match  \
# id
# 335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                              venue  \
# id
# 335982                       M Chinnaswamy Stadium
# 335983  Punjab Cricket Association Stadium, Mohali
# 335984                            Feroz Shah Kotla
# 335985                            Wankhede Stadium
# 335986                                Eden Gardens
#
#                               team1                        team2  \
# id
# 335982  Royal Challengers Bangalore        Kolkata Knight Riders
# 335983              Kings XI Punjab          Chennai Super Kings
# ...

# %% [markdown]
# ####Indexing, Selecting & Assigning

# %% [markdown]
# # Native accessors

# %%
Matches
# Out:
#           season        city        date   match_type  player_of_match  \
# id
# 335982   2007/08   Bangalore  2008-04-18       League      BB McCullum
# 335983   2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 335984   2007/08       Delhi  2008-04-19       League      MF Maharoof
# 335985   2007/08      Mumbai  2008-04-20       League       MV Boucher
# 335986   2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...          ...         ...         ...          ...              ...
# 1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                      venue  \
# id
# ...

# %%
Matches.city
# Out:
# id
# 335982      Bangalore
# 335983     Chandigarh
# 335984          Delhi
# 335985         Mumbai
# 335986        Kolkata
#               ...
# 1426307     Hyderabad
# 1426309     Ahmedabad
# 1426310     Ahmedabad
# 1426311       Chennai
# 1426312       Chennai
# Name: city, Length: 1095, dtype: object

# %%
Matches['city']
# Out:
# id
# 335982      Bangalore
# 335983     Chandigarh
# 335984          Delhi
# 335985         Mumbai
# 335986        Kolkata
#               ...
# 1426307     Hyderabad
# 1426309     Ahmedabad
# 1426310     Ahmedabad
# 1426311       Chennai
# 1426312       Chennai
# Name: city, Length: 1095, dtype: object

# %%
Matches['city'][335982]
# Out:
# 'Bangalore'

# %%
##Indexing in pandas

# %%
Matches.iloc[0]
# Out:
# season                                 2007/08
# city                                 Bangalore
# date                                2008-04-18
# match_type                              League
# player_of_match                    BB McCullum
# venue                    M Chinnaswamy Stadium
# team1              Royal Challengers Bangalore
# team2                    Kolkata Knight Riders
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                            140.0
# target_runs                              223.0
# target_overs                              20.0
# super_over                                   N
# method                                     NaN
# umpire1                              Asad Rauf
# umpire2                            RE Koertzen
# Name: 335982, dtype: object

# %%
Matches.iloc[:, 0]
# Out:
# id
# 335982     2007/08
# 335983     2007/08
# 335984     2007/08
# 335985     2007/08
# 335986     2007/08
#             ...
# 1426307       2024
# 1426309       2024
# 1426310       2024
# 1426311       2024
# 1426312       2024
# Name: season, Length: 1095, dtype: object

# %%
Matches.iloc[:3, 0]
# Out:
# id
# 335982    2007/08
# 335983    2007/08
# 335984    2007/08
# Name: season, dtype: object

# %%
Matches.iloc[1:3, 0]
# Out:
# id
# 335983    2007/08
# 335984    2007/08
# Name: season, dtype: object

# %%
Matches.iloc[[0, 1, 2], 0]
# Out:
# id
# 335982    2007/08
# 335983    2007/08
# 335984    2007/08
# Name: season, dtype: object

# %%
Matches.iloc[-5:]
# Out:
#         season       city        date   match_type  player_of_match  \
# id
# 1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                      venue  \
# id
# 1426307  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1426309                   Narendra Modi Stadium, Ahmedabad
# 1426310                   Narendra Modi Stadium, Ahmedabad
# 1426311           MA Chidambaram Stadium, Chepauk, Chennai
# 1426312           MA Chidambaram Stadium, Chepauk, Chennai
#
#                                team1                  team2  \
# id
# 1426307                 Punjab Kings    Sunrisers Hyderabad
# 1426309          Sunrisers Hyderabad  Kolkata Knight Riders
# ...

# %% [markdown]
# # Label-based selection

# %%
Matches.loc[335982, 'city']
# Out:
# 'Bangalore'

# %%
Matches.loc[:, ['team1', 'team2', 'winner\']]
# Out:
#   Cell In[52], line 1
#     Matches.loc[:, ['team1', 'team2', 'winner\']]
#                                       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
##Conditional selection

# %%
Matches.city == 'Hyderabad'
# Out:
# id
# 335982     False
# 335983     False
# 335984     False
# 335985     False
# 335986     False
#            ...
# 1426307     True
# 1426309    False
# 1426310    False
# 1426311    False
# 1426312    False
# Name: city, Length: 1095, dtype: bool

# %%
Matches.loc[(Matches.city == 'Hyderabad') & (Matches.target_overs >= 10)]
# Out:
#           season       city        date match_type  player_of_match  \
# id
# 335988   2007/08  Hyderabad  2008-04-22     League         V Sehwag
# 335990   2007/08  Hyderabad  2008-04-24     League        YK Pathan
# 335999   2007/08  Hyderabad  2008-05-01     League         SE Marsh
# 336014   2007/08  Hyderabad  2008-05-11     League       SC Ganguly
# 336024   2007/08  Hyderabad  2008-05-18     League         DJ Bravo
# ...          ...        ...         ...        ...              ...
# 1422136     2024  Hyderabad  2024-04-05     League  Abhishek Sharma
# 1426279     2024  Hyderabad  2024-04-25     League       RM Patidar
# 1426288     2024  Hyderabad  2024-05-02     League          B Kumar
# 1426295     2024  Hyderabad  2024-05-08     League          TM Head
# 1426307     2024  Hyderabad  2024-05-19     League  Abhishek Sharma
#
#                                                      venue  \
# id
# 335988           Rajiv Gandhi International Stadium, Uppal
# ...

# %%
Matches.loc[Matches.city.isin(['Hyderabad', 'Ahmedabad'])]
# Out:
#           season       city        date   match_type  player_of_match  \
# id
# 335988   2007/08  Hyderabad  2008-04-22       League         V Sehwag
# 335990   2007/08  Hyderabad  2008-04-24       League        YK Pathan
# 335999   2007/08  Hyderabad  2008-05-01       League         SE Marsh
# 336014   2007/08  Hyderabad  2008-05-11       League       SC Ganguly
# 336024   2007/08  Hyderabad  2008-05-18       League         DJ Bravo
# ...          ...        ...         ...          ...              ...
# 1426295     2024  Hyderabad  2024-05-08       League          TM Head
# 1426297     2024  Ahmedabad  2024-05-10       League     Shubman Gill
# 1426307     2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1426309     2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1426310     2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
#
#                                                      venue  \
# id
# ...

# %%
Matches.loc[Matches.result_margin.notnull()]
# Out:
#           season        city        date   match_type  player_of_match  \
# id
# 335982   2007/08   Bangalore  2008-04-18       League      BB McCullum
# 335983   2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 335984   2007/08       Delhi  2008-04-19       League      MF Maharoof
# 335985   2007/08      Mumbai  2008-04-20       League       MV Boucher
# 335986   2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...          ...         ...         ...          ...              ...
# 1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                      venue  \
# id
# ...

# %% [markdown]
# # Summary Functions and Maps

# %%
Matches.winner.describe()
# Out:
# count               1090
# unique                19
# top       Mumbai Indians
# freq                 144
# Name: winner, dtype: object

# %%
Matches.target_overs.describe()
# Out:
# count    1092.000000
# mean       19.759341
# std         1.581108
# min         5.000000
# 25%        20.000000
# 50%        20.000000
# 75%        20.000000
# max        20.000000
# Name: target_overs, dtype: float64

# %%
Matches.target_overs.mean()
# Out:
# 19.75934065934066

# %%
Matches.winner.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Deccan Chargers', 'Mumbai Indians',
#        'Pune Warriors', 'Kochi Tuskers Kerala', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
Matches.winner.value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %% [markdown]
# # Maps

# %%
###A map is a term, borrowed from mathematics, for a function that takes one set of values and "maps" them to another set of values
Matches_target_overs_mean = Matches.target_overs.mean()
Matches.target_overs.map(lambda p: p - Matches_target_overs_mean)
# Out:
# id
# 335982     0.240659
# 335983     0.240659
# 335984     0.240659
# 335985     0.240659
# 335986     0.240659
#              ...
# 1426307    0.240659
# 1426309    0.240659
# 1426310    0.240659
# 1426311    0.240659
# 1426312    0.240659
# Name: target_overs, Length: 1095, dtype: float64

# %%
# Define the function to adjust 'result_margin' in each row
def remean_result_margin(row):
    # Subtract the average 'result_margin' from each row's 'result_margin'
    row['result_margin'] = row['result_margin'] - Matches['result_margin'].mean()
    return row

# Apply the function to each row
Matches = Matches.apply(remean_result_margin,axis='columns')

# %%
Matches.head(1)
# Out:
#          season       city        date match_type player_of_match  \
# id
# 335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                         venue                        team1  \
# id
# 335982  M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#                         team2                  toss_winner toss_decision  \
# id
# 335982  Kolkata Knight Riders  Royal Challengers Bangalore         field
#
#                        winner result  result_margin  target_runs  \
# id
# 335982  Kolkata Knight Riders   runs     122.740706        223.0
#
#         target_overs super_over method    umpire1      umpire2
# id
# 335982          20.0          N    NaN  Asad Rauf  RE Koertzen

# %%
Matches.city + " - " + Matches.venue
# Out:
# id
# 335982                     Bangalore - M Chinnaswamy Stadium
# 335983     Chandigarh - Punjab Cricket Association Stadiu...
# 335984                              Delhi - Feroz Shah Kotla
# 335985                             Mumbai - Wankhede Stadium
# 335986                                Kolkata - Eden Gardens
#                                  ...
# 1426307    Hyderabad - Rajiv Gandhi International Stadium...
# 1426309         Ahmedabad - Narendra Modi Stadium, Ahmedabad
# 1426310         Ahmedabad - Narendra Modi Stadium, Ahmedabad
# 1426311    Chennai - MA Chidambaram Stadium, Chepauk, Che...
# 1426312    Chennai - MA Chidambaram Stadium, Chepauk, Che...
# Length: 1095, dtype: object

# %% [markdown]
# # Grouping and Sorting

# %%
Matches.groupby('result_margin').result_margin.count()
# Out:
# result_margin
# -16.259294      18
# -15.259294      21
# -14.259294      39
# -13.259294      74
# -12.259294     109
#               ...
#  112.740706      1
#  120.740706      1
#  122.740706      1
#  126.740706      1
#  128.740706      1
# Name: result_margin, Length: 98, dtype: int64

# %%
Matches.groupby('result_margin').result_margin.min()
# Out:
# result_margin
# -16.259294     -16.259294
# -15.259294     -15.259294
# -14.259294     -14.259294
# -13.259294     -13.259294
# -12.259294     -12.259294
#                   ...
#  112.740706    112.740706
#  120.740706    120.740706
#  122.740706    122.740706
#  126.740706    126.740706
#  128.740706    128.740706
# Name: result_margin, Length: 98, dtype: float64

# %%
Matches.groupby('match_type').apply(lambda df: df.winner.iloc[0])
# Out:
# C:\Users\Dolli\AppData\Local\Temp\ipykernel_16004\1666491659.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   Matches.groupby('match_type').apply(lambda df: df.winner.iloc[0])
# match_type
# 3rd Place Play-Off    Royal Challengers Bangalore
# Elimination Final                  Mumbai Indians
# Eliminator                       Rajasthan Royals
# Final                            Rajasthan Royals
# League                      Kolkata Knight Riders
# Qualifier 1                   Chennai Super Kings
# Qualifier 2           Royal Challengers Bangalore
# Semi Final                       Rajasthan Royals
# dtype: object

# %%
Matches.sample(10)
# Out:
#           season       city        date match_type player_of_match  \
# id
# 1426276     2024     Jaipur  2024-04-22     League  Sandeep Sharma
# 729305      2014  Abu Dhabi  2014-04-26     League        PV Tambe
# 1136580     2018  Hyderabad  2018-04-22     League       AT Rayudu
# 392235      2009  Centurion  2009-05-21     League        V Sehwag
# 1216495  2020/21        NaN  2020-11-03     League        S Nadeem
# 734007      2014  Hyderabad  2014-05-14     League         WP Saha
# 1426283     2024  Ahmedabad  2024-04-28     League        WG Jacks
# 734021      2014  Hyderabad  2014-05-20     League       DA Warner
# 829753      2015    Chennai  2015-04-25     League     BB McCullum
# 1426305     2024     Mumbai  2024-05-17     League        N Pooran
#
#                                              venue                 team1  \
# id
# 1426276             Sawai Mansingh Stadium, Jaipur        Mumbai Indians
# ...

# %%
Matches.head(10)
# Out:
#          season        city        date match_type player_of_match  \
# id
# 335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                              venue  \
# id
# 335982                       M Chinnaswamy Stadium
# 335983  Punjab Cricket Association Stadium, Mohali
# 335984                            Feroz Shah Kotla
# ...

# %%
import matplotlib.pyplot as plt
Matches['date'] = pd.to_datetime(Matches['date'], errors='coerce')

# Sort data by date to ensure a proper timeline
Matches = Matches.sort_values(by='date')

# Plotting the result margin over time
plt.figure(figsize=(14, 6))
plt.plot(Matches['date'], Matches['result_margin'], color='blue', alpha=0.7, label='Result Margin')
plt.title('Trend of Result Margin Over Time')
plt.xlabel('Date')
plt.ylabel('Result Margin')
plt.legend()
plt.show()

# %%
# Convert 'date' column to datetime format
Matches['date'] = pd.to_datetime(Matches['date'], errors='coerce')

# Sort by date
Matches = Matches.sort_values(by='date').reset_index(drop=True)

# Calculate the change in 'result_margin' between consecutive matches
Matches['margin_change'] = Matches['result_margin'].diff()

# Identify up and down trends
Matches['trend'] = Matches['margin_change'].apply(lambda x: 'uprun' if x > 0 else ('downrun' if x < 0 else 'no change'))

# Plotting
plt.figure(figsize=(14, 6))

# Plot uprun segments
plt.plot(Matches['date'][Matches['trend'] == 'uprun'], 
         Matches['result_margin'][Matches['trend'] == 'uprun'], 
         color='green', label='Uprun (Increase)', alpha=0.7)

# Plot downrun segments
plt.plot(Matches['date'][Matches['trend'] == 'downrun'], 
         Matches['result_margin'][Matches['trend'] == 'downrun'], 
         color='red', label='Downrun (Decrease)', alpha=0.7)

# Add title and labels
plt.title('Uprun and Downrun Trends in Result Margin Over Time')
plt.xlabel('Date')
plt.ylabel('Result Margin')
plt.legend()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 Matches.loc[:3,["player_of_match","date","season"]]
#
# ...
