# %%
import pandas as pd

# %%
match= pd.read_csv("matches.csv")

# %%
match.head(5)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
match.tail(10)
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1085  1426300   2024  Bengaluru  2024-05-12       League          C Green
# 1086  1426302   2024      Delhi  2024-05-14       League         I Sharma
# 1087  1426303   2024   Guwahati  2024-05-15       League        SM Curran
# 1088  1426305   2024     Mumbai  2024-05-17       League         N Pooran
# 1089  1426306   2024  Bengaluru  2024-05-18       League     F du Plessis
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1085                   M Chinnaswamy Stadium, Bengaluru
# ...

# %%
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
match.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
match["venue"].describe()
# Out:
# count             1095
# unique              58
# top       Eden Gardens
# freq                77
# Name: venue, dtype: object

# %%
match["target_runs"].describe()
# Out:
# count    1092.000000
# mean      165.684066
# std        33.427048
# min        43.000000
# 25%       146.000000
# 50%       166.000000
# 75%       187.000000
# max       288.000000
# Name: target_runs, dtype: float64

# %%
match.columns.unique()
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
match.drop("match_type", axis=1, inplace=True)
match.columns.unique()
# Out:
# Index(['id', 'season', 'city', 'date', 'player_of_match', 'venue', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'target_runs', 'target_overs', 'super_over', 'method',
#        'umpire1', 'umpire2'],
#       dtype='object')

# %%
match.replace('Royal Challengers Bangalore', 'RCB', inplace=True)
match.head()
# Out:
#        id   season        city        date player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue                  team1  \
# 0                       M Chinnaswamy Stadium                    RCB
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
# 2                            Feroz Shah Kotla       Delhi Daredevils
# 3                            Wankhede Stadium         Mumbai Indians
# 4                                Eden Gardens  Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  \
# 0  Kolkata Knight Riders                  RCB         field
# 1    Chennai Super Kings  Chennai Super Kings           bat
# ...

# %%
match.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
match_group=match.groupby("result_margin")
match_group.first()
# Out:
#                     id   season        city        date player_of_match  \
# result_margin
# 1.0             336028  2007/08      Mumbai  2008-05-21        SE Marsh
# 2.0             392224     2009      Durban  2009-05-14     LRPL Taylor
# 3.0             335990  2007/08   Hyderabad  2008-04-24       YK Pathan
# 4.0             335995  2007/08  Chandigarh  2008-04-27       SM Katich
# 5.0             335985  2007/08      Mumbai  2008-04-20      MV Boucher
# ...                ...      ...         ...         ...             ...
# 130.0           598027     2013   Bangalore  2013-04-23        CH Gayle
# 138.0           829785     2015   Bangalore  2015-05-06        CH Gayle
# 140.0           335982  2007/08   Bangalore  2008-04-18     BB McCullum
# 144.0           980987     2016   Bangalore  2016-05-14  AB de Villiers
# 146.0          1082635     2017       Delhi  2017-05-06     LMP Simmons
#
#                                                     venue             team1  \
# ...

# %%
match_sorted=match.sort_values(by="target_runs", ascending=True)
match_sorted.head()
# Out:
#           id   season       city        date  player_of_match  \
# 429   733993     2014      Delhi  2014-05-10         DW Steyn
# 633  1082648     2017  Bangalore  2017-05-17  NM Coulter-Nile
# 221   501245     2011    Kolkata  2011-05-07    Iqbal Abdulla
# 41    336025  2007/08    Kolkata  2008-05-18          M Ntini
# 60    392183     2009  Cape Town  2009-04-19       DL Vettori
#
#                      venue                  team1                  team2  \
# 429       Feroz Shah Kotla       Delhi Daredevils    Sunrisers Hyderabad
# 633  M Chinnaswamy Stadium    Sunrisers Hyderabad  Kolkata Knight Riders
# 221           Eden Gardens  Kolkata Knight Riders    Chennai Super Kings
# 41            Eden Gardens  Kolkata Knight Riders    Chennai Super Kings
# 60                Newlands       Delhi Daredevils        Kings XI Punjab
#
#                toss_winner toss_decision                 winner   result  \
# 429    Sunrisers Hyderabad         field    Sunrisers Hyderabad  wickets
# ...

# %%
match_filter=match[match["target_runs"]>200]
match_filter.head()
# Out:
#         id   season        city        date player_of_match  \
# 0   335982  2007/08   Bangalore  2008-04-18     BB McCullum
# 1   335983  2007/08  Chandigarh  2008-04-19      MEK Hussey
# 7   335989  2007/08     Chennai  2008-04-23       ML Hayden
# 8   335990  2007/08   Hyderabad  2008-04-24       YK Pathan
# 31  336014  2007/08   Hyderabad  2008-05-11      SC Ganguly
#
#                                          venue                team1  \
# 0                        M Chinnaswamy Stadium                  RCB
# 1   Punjab Cricket Association Stadium, Mohali      Kings XI Punjab
# 7              MA Chidambaram Stadium, Chepauk  Chennai Super Kings
# 8    Rajiv Gandhi International Stadium, Uppal      Deccan Chargers
# 31   Rajiv Gandhi International Stadium, Uppal      Deccan Chargers
#
#                     team2            toss_winner toss_decision  \
# 0   Kolkata Knight Riders                    RCB         field
# 1     Chennai Super Kings    Chennai Super Kings           bat
# ...

# %%
match_filter=match[match["target_runs"]<200]
match_filter.head()
# Out:
#        id   season       city        date player_of_match  \
# 2  335984  2007/08      Delhi  2008-04-19     MF Maharoof
# 3  335985  2007/08     Mumbai  2008-04-20      MV Boucher
# 4  335986  2007/08    Kolkata  2008-04-20       DJ Hussey
# 5  335987  2007/08     Jaipur  2008-04-21       SR Watson
# 6  335988  2007/08  Hyderabad  2008-04-22        V Sehwag
#
#                                        venue                  team1  \
# 2                           Feroz Shah Kotla       Delhi Daredevils
# 3                           Wankhede Stadium         Mumbai Indians
# 4                               Eden Gardens  Kolkata Knight Riders
# 5                     Sawai Mansingh Stadium       Rajasthan Royals
# 6  Rajiv Gandhi International Stadium, Uppal        Deccan Chargers
#
#               team2       toss_winner toss_decision                 winner  \
# 2  Rajasthan Royals  Rajasthan Royals           bat       Delhi Daredevils
# ...

# %%
target_mean = match.target_runs.mean()
match.target_runs.map(lambda p: p - target_mean)
# Out:
# 0       57.315934
# 1       75.315934
# 2      -35.684066
# 3        0.315934
# 4      -54.684066
#           ...
# 1090    49.315934
# 1091    -5.684066
# 1092     7.315934
# 1093    10.315934
# 1094   -51.684066
# Name: target_runs, Length: 1095, dtype: float64

# %%
result_mean = match.result_margin.mean()
match.result_margin.map(lambda p: p - result_mean)
# Out:
# 0       122.740706
# 1        15.740706
# 2        -8.259294
# 3       -12.259294
# 4       -12.259294
#            ...
# 1090    -13.259294
# 1091     -9.259294
# 1092    -13.259294
# 1093     18.740706
# 1094     -9.259294
# Name: result_margin, Length: 1095, dtype: float64

# %%
def remean_point(row):
    row.target_runs = row.target_runs - target_mean
    return row

modifydata_match=match.apply(remean_point, axis='columns')
modifydata_match.head(5)
# Out:
#        id   season        city        date player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue                  team1  \
# 0                       M Chinnaswamy Stadium                    RCB
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
# 2                            Feroz Shah Kotla       Delhi Daredevils
# 3                            Wankhede Stadium         Mumbai Indians
# 4                                Eden Gardens  Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  \
# 0  Kolkata Knight Riders                  RCB         field
# 1    Chennai Super Kings  Chennai Super Kings           bat
# ...

# %%
match.head(5)
# Out:
#        id   season        city        date player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue                  team1  \
# 0                       M Chinnaswamy Stadium                    RCB
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
# 2                            Feroz Shah Kotla       Delhi Daredevils
# 3                            Wankhede Stadium         Mumbai Indians
# 4                                Eden Gardens  Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  \
# 0  Kolkata Knight Riders                  RCB         field
# 1    Chennai Super Kings  Chennai Super Kings           bat
# ...

# %%
match.team1+" - "+match.team2+" / "+match.winner
# Out:
# 0       RCB - Kolkata Knight Riders / Kolkata Knight R...
# 1       Kings XI Punjab - Chennai Super Kings / Chenna...
# 2       Delhi Daredevils - Rajasthan Royals / Delhi Da...
# 3                              Mumbai Indians - RCB / RCB
# 4       Kolkata Knight Riders - Deccan Chargers / Kolk...
#                               ...
# 1090    Punjab Kings - Sunrisers Hyderabad / Sunrisers...
# 1091    Sunrisers Hyderabad - Kolkata Knight Riders / ...
# 1092    Royal Challengers Bengaluru - Rajasthan Royals...
# 1093    Sunrisers Hyderabad - Rajasthan Royals / Sunri...
# 1094    Sunrisers Hyderabad - Kolkata Knight Riders / ...
# Length: 1095, dtype: object

# %%
match.groupby("team1").target_runs.mean()
# Out:
# team1
# Chennai Super Kings            170.773438
# Deccan Chargers                160.666667
# Delhi Capitals                 173.097561
# Delhi Daredevils               159.809524
# Gujarat Lions                  166.875000
# Gujarat Titans                 177.714286
# Kings XI Punjab                166.032609
# Kochi Tuskers Kerala           145.571429
# Kolkata Knight Riders          161.975207
# Lucknow Super Giants           182.363636
# Mumbai Indians                 167.317073
# Pune Warriors                  146.652174
# Punjab Kings                   169.096774
# RCB                            165.567164
# Rajasthan Royals               164.613861
# Rising Pune Supergiant         163.571429
# Rising Pune Supergiants        153.142857
# Royal Challengers Bengaluru    196.333333
# Sunrisers Hyderabad            162.593023
# Name: target_runs, dtype: float64

# %%
match.groupby("team1").team1.count()
# Out:
# team1
# Chennai Super Kings            128
# Deccan Chargers                 39
# Delhi Capitals                  41
# Delhi Daredevils                85
# Gujarat Lions                   16
# Gujarat Titans                  21
# Kings XI Punjab                 92
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders          121
# Lucknow Super Giants            23
# Mumbai Indians                 123
# Pune Warriors                   23
# Punjab Kings                    31
# RCB                            135
# Rajasthan Royals               101
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Royal Challengers Bengaluru      9
# Sunrisers Hyderabad             86
# Name: team1, dtype: int64

# %%
match.groupby("team1").target_runs.min()
# Out:
# team1
# Chennai Super Kings             98.0
# Deccan Chargers                102.0
# Delhi Capitals                 111.0
# Delhi Daredevils                43.0
# Gujarat Lions                  125.0
# Gujarat Titans                  90.0
# Kings XI Punjab                 68.0
# Kochi Tuskers Kerala            98.0
# Kolkata Knight Riders           52.0
# Lucknow Super Giants           154.0
# Mumbai Indians                  68.0
# Pune Warriors                  100.0
# Punjab Kings                   107.0
# RCB                             63.0
# Rajasthan Royals                71.0
# Rising Pune Supergiant          74.0
# Rising Pune Supergiants         58.0
# Royal Challengers Bengaluru    173.0
# Sunrisers Hyderabad             48.0
# Name: target_runs, dtype: float64

# %%
match.groupby("team1").target_runs.max()
# Out:
# team1
# Chennai Super Kings            247.0
# Deccan Chargers                215.0
# Delhi Capitals                 258.0
# Delhi Daredevils               232.0
# Gujarat Lions                  214.0
# Gujarat Titans                 234.0
# Kings XI Punjab                241.0
# Kochi Tuskers Kerala           179.0
# Kolkata Knight Riders          273.0
# Lucknow Super Giants           258.0
# Mumbai Indians                 236.0
# Pune Warriors                  188.0
# Punjab Kings                   222.0
# RCB                            264.0
# Rajasthan Royals               223.0
# Rising Pune Supergiant         206.0
# Rising Pune Supergiants        196.0
# Royal Challengers Bengaluru    242.0
# Sunrisers Hyderabad            288.0
# Name: target_runs, dtype: float64

# %%
match.groupby("team1").target_runs.agg([len, min, max])
# Out:
# <ipython-input-26-17a1b12af35d>:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   match.groupby("team1").target_runs.agg([len, min, max])
# <ipython-input-26-17a1b12af35d>:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   match.groupby("team1").target_runs.agg([len, min, max])
#                              len    min    max
# team1
# Chennai Super Kings          128   98.0  247.0
# Deccan Chargers               39  102.0  215.0
# Delhi Capitals                41  111.0  258.0
# Delhi Daredevils              85   43.0  232.0
# Gujarat Lions                 16  125.0  214.0
# ...

# %%
match["team1"][7]
# Out:
# 'Chennai Super Kings'

# %%
match.iloc[0]
# Out:
# id                                335982
# season                           2007/08
# city                           Bangalore
# date                          2008-04-18
# player_of_match              BB McCullum
# venue              M Chinnaswamy Stadium
# team1                                RCB
# team2              Kolkata Knight Riders
# toss_winner                          RCB
# toss_decision                      field
# winner             Kolkata Knight Riders
# result                              runs
# result_margin                      140.0
# target_runs                        223.0
# target_overs                        20.0
# super_over                             N
# method                               NaN
# umpire1                        Asad Rauf
# umpire2                      RE Koertzen
# Name: 0, dtype: object

# %%
match.iloc[2:5, 3]
# Out:
# 2    2008-04-19
# 3    2008-04-20
# 4    2008-04-20
# Name: date, dtype: object

# %%
match.iloc[[-4,5,-6], -2]
# Out:
# 1091    AK Chaudhary
# 5          Aleem Dar
# 1089         A Totre
# Name: umpire1, dtype: object

# %%
match.loc[:5, ["player_of_match", "date", "season"]]
# Out:
#   player_of_match        date   season
# 0     BB McCullum  2008-04-18  2007/08
# 1      MEK Hussey  2008-04-19  2007/08
# 2     MF Maharoof  2008-04-19  2007/08
# 3      MV Boucher  2008-04-20  2007/08
# 4       DJ Hussey  2008-04-20  2007/08
# 5       SR Watson  2008-04-21  2007/08

# %%
match.loc[:15, ["team1", "team2", "winner"]]
# Out:
#                     team1                  team2                 winner
# 0                     RCB  Kolkata Knight Riders  Kolkata Knight Riders
# 1         Kings XI Punjab    Chennai Super Kings    Chennai Super Kings
# 2        Delhi Daredevils       Rajasthan Royals       Delhi Daredevils
# 3          Mumbai Indians                    RCB                    RCB
# 4   Kolkata Knight Riders        Deccan Chargers  Kolkata Knight Riders
# 5        Rajasthan Royals        Kings XI Punjab       Rajasthan Royals
# 6         Deccan Chargers       Delhi Daredevils       Delhi Daredevils
# 7     Chennai Super Kings         Mumbai Indians    Chennai Super Kings
# 8         Deccan Chargers       Rajasthan Royals       Rajasthan Royals
# 9         Kings XI Punjab         Mumbai Indians        Kings XI Punjab
# 10                    RCB       Rajasthan Royals       Rajasthan Royals
# 11    Chennai Super Kings  Kolkata Knight Riders    Chennai Super Kings
# ...

# %%
match.team1=="Royal Challengers Bangalore"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# 1094    False
# Name: team1, Length: 1095, dtype: bool

# %%
match.loc[match.team1=="Royal Challengers Bangalore"]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2]
# Index: []

# %%
match.loc[(match.team1=="Chennai Super Kings")&(match.target_runs>=150)]
# Out:
#            id   season        city        date player_of_match  \
# 7      335989  2007/08     Chennai  2008-04-23       ML Hayden
# 19     336001  2007/08     Chennai  2008-05-02        V Sehwag
# 30     336013  2007/08     Chennai  2008-05-10        L Balaji
# 48     336033  2007/08     Chennai  2008-05-24       JA Morkel
# 57     336040  2007/08      Mumbai  2008-06-01       YK Pathan
# ...       ...      ...         ...         ...             ...
# 1057  1426272     2024     Lucknow  2024-04-19        KL Rahul
# 1062  1426277     2024     Chennai  2024-04-23      MP Stoinis
# 1069  1426284     2024     Chennai  2024-04-28      RD Gaikwad
# 1072  1426287     2024     Chennai  2024-05-01   Harpreet Brar
# 1076  1426291     2024  Dharamsala  2024-05-05       RA Jadeja
#
#                                                   venue                team1  \
# 7                       MA Chidambaram Stadium, Chepauk  Chennai Super Kings
# ...

# %%
match.loc[(match.team1=="Royal Challengers Bangalore")&(match.winner=="Royal Challengers Bangalore")]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, target_runs, target_overs, super_over, method, umpire1, umpire2]
# Index: []

# %%
match.loc[match.city.isin(["Chennai", "Bangalore"])]
# Out:
#            id   season       city        date  player_of_match  \
# 0      335982  2007/08  Bangalore  2008-04-18      BB McCullum
# 7      335989  2007/08    Chennai  2008-04-23        ML Hayden
# 10     335992  2007/08  Bangalore  2008-04-26        SR Watson
# 11     335993  2007/08    Chennai  2008-04-26         JDP Oram
# 14     335996  2007/08  Bangalore  2008-04-28         MS Dhoni
# ...       ...      ...        ...         ...              ...
# 1069  1426284     2024    Chennai  2024-04-28       RD Gaikwad
# 1072  1426287     2024    Chennai  2024-05-01    Harpreet Brar
# 1084  1426299     2024    Chennai  2024-05-12  Simarjeet Singh
# 1093  1426311     2024    Chennai  2024-05-24    Shahbaz Ahmed
# 1094  1426312     2024    Chennai  2024-05-26         MA Starc
#
#                                          venue                team1  \
# 0                        M Chinnaswamy Stadium                  RCB
# 7              MA Chidambaram Stadium, Chepauk  Chennai Super Kings
# ...

# %%
match.loc[match.result_margin.notnull()]
# Out:
#            id   season        city        date  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20        DJ Hussey
# ...       ...      ...         ...         ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26         MA Starc
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# ...

# %%
match["player_of_match"]="MA Starc"
match.head()
# Out:
#        id   season        city        date player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18        MA Starc
# 1  335983  2007/08  Chandigarh  2008-04-19        MA Starc
# 2  335984  2007/08       Delhi  2008-04-19        MA Starc
# 3  335985  2007/08      Mumbai  2008-04-20        MA Starc
# 4  335986  2007/08     Kolkata  2008-04-20        MA Starc
#
#                                         venue                  team1  \
# 0                       M Chinnaswamy Stadium                    RCB
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
# 2                            Feroz Shah Kotla       Delhi Daredevils
# 3                            Wankhede Stadium         Mumbai Indians
# 4                                Eden Gardens  Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  \
# 0  Kolkata Knight Riders                  RCB         field
# 1    Chennai Super Kings  Chennai Super Kings           bat
# ...

# %%
match["team2"]=range(len(match), 0, -1)
match["team2"]
# Out:
# 0       1095
# 1       1094
# 2       1093
# 3       1092
# 4       1091
#         ...
# 1090       5
# 1091       4
# 1092       3
# 1093       2
# 1094       1
# Name: team2, Length: 1095, dtype: int64

# %%
match.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# player_of_match       0
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
match.fillna("none", inplace=True)
match.isnull().sum()
# Out:
# <ipython-input-42-627266cfe357>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'none' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   match.fillna("none", inplace=True)
# id                 0
# season             0
# city               0
# date               0
# player_of_match    0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
match.replace("Bangalore", "Benguluru", inplace=True)
match.head()
# Out:
#        id   season        city        date player_of_match  \
# 0  335982  2007/08   Benguluru  2008-04-18        MA Starc
# 1  335983  2007/08  Chandigarh  2008-04-19        MA Starc
# 2  335984  2007/08       Delhi  2008-04-19        MA Starc
# 3  335985  2007/08      Mumbai  2008-04-20        MA Starc
# 4  335986  2007/08     Kolkata  2008-04-20        MA Starc
#
#                                         venue                  team1  team2  \
# 0                       M Chinnaswamy Stadium                    RCB   1095
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab   1094
# 2                            Feroz Shah Kotla       Delhi Daredevils   1093
# 3                            Wankhede Stadium         Mumbai Indians   1092
# 4                                Eden Gardens  Kolkata Knight Riders   1091
#
#            toss_winner toss_decision                 winner   result  \
# 0                  RCB         field  Kolkata Knight Riders     runs
# ...
