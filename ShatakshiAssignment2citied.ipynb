# 347         Kolkata Knight Riders           bat          Chennai Super Kings
# 374                Mumbai Indians           bat               Mumbai Indians
# 558              Delhi Daredevils         field             Delhi Daredevils
# 747         Kolkata Knight Riders         field        Kolkata Knight Riders
# 579         Kolkata Knight Riders         field        Kolkata Knight Riders
# 96    Royal Challengers Bangalore         field  Royal Challengers Bangalore
# 758           Sunrisers Hyderabad         field  Royal Challengers Bangalore
#
#        result  result_margin  target_runs  target_overs super_over method  \
# 49    wickets            5.0        166.0          20.0          N    NaN
# 104      runs            1.0        135.0          20.0          N    NaN
# 620      runs          146.0        213.0          20.0          N    NaN
# 1078  wickets            7.0        174.0          20.0          N    NaN
# 140      runs           40.0        178.0          20.0          N    NaN
# 515   wickets            3.0        140.0          20.0          N    NaN
# 212      runs           19.0        166.0          20.0          N    NaN
# 387      runs           14.0        167.0          20.0          N    NaN
# 347   wickets            4.0        120.0          20.0          N    NaN
# 374      runs           65.0        171.0          20.0          N    NaN
# 558   wickets            7.0        147.0          20.0          N    NaN
# 747   wickets            7.0        184.0          20.0          N    NaN
# 579   wickets           10.0        184.0          20.0          N    NaN
# 96    wickets            6.0        174.0          20.0          N    NaN
# 758      runs           10.0        164.0          20.0          N    NaN
#
#               umpire1        umpire2
# 49          Asad Rauf    RE Koertzen
# 104            S Ravi      RB Tiffin
# 620       Nitin Menon      CK Nandan
# 1078    Navdeep Singh   Tapan Sharma
# 140         SS Hazare     SJA Taufel
# 515      AK Chaudhary    CB Gaffaney
# 212         Aleem Dar      RB Tiffin
# 387         Asad Rauf       S Asnani
# 347         Asad Rauf   AK Chaudhary
# 374   HDPK Dharmasena         S Ravi
# 558        K Bharatan      M Erasmus
# 747      BNJ Oxenford  C Shamshuddin
# 579       Nitin Menon      CK Nandan
# 96          M Erasmus      SS Hazare
# 758       AY Dandekar    Nitin Menon

# %%
matches.city.isnull().sum()
# Out:
# np.int64(51)

# %%
matches.city.fillna(matches.venue,inplace=True)
# Out:
# C:\Users\shata\AppData\Local\Temp\ipykernel_17876\2335265080.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   matches.city.fillna(matches.venue,inplace=True)

# %%
matches.city.isnull().sum()
# Out:
# np.int64(0)

# %%
matches.city.unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Sharjah Cricket Stadium',
#        'Dubai International Cricket Stadium', 'Rajkot', 'Kanpur',
#        'Bengaluru', 'Dubai', 'Sharjah', 'Navi Mumbai', 'Lucknow',
#        'Guwahati', 'Mohali'], dtype=object)

# %%
matches.city.nunique()
# Out:
# 38

# %%
matches.city.replace("Dubai International Cricket Stadium","Dubai",inplace=True)
matches.city.replace("Sharjah Cricket Stadium","Sharjah",inplace=True)

# %%
matches.replace("Bengaluru","Bangalore",inplace=True)

# %%
matches.city.unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Sharjah', 'Dubai', 'Rajkot', 'Kanpur', 'Navi Mumbai',
#        'Lucknow', 'Guwahati', 'Mohali'], dtype=object)

# %%
matches.city.nunique()
# Out:
# 35

# %%
topcities=matches.city.value_counts()
top_20_cities=topcities.head(20)
top_20_cities
# Out:
# city
# Mumbai           173
# Bangalore         94
# Kolkata           93
# Delhi             90
# Chennai           85
# Hyderabad         77
# Chandigarh        61
# Jaipur            57
# Pune              51
# Dubai             46
# Abu Dhabi         37
# Ahmedabad         36
# Sharjah           28
# Durban            15
# Visakhapatnam     15
# Lucknow           14
# Dharamsala        13
# Centurion         12
# Rajkot            10
# Navi Mumbai        9
# Name: count, dtype: int64

# %%
top_20_cities.plot(kind='bar',color='blue')
plt.title("Top 20 cities based on number of matches",color='darkblue')
plt.xlabel('City')
plt.ylabel('Number of Matches')
plt.show()
