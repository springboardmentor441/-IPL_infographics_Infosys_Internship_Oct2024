# %%
import pandas as pd
df=pd.read_csv("matches.csv")
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df.iloc[:,0]
# Out:
# 0        335982
# 1        335983
# 2        335984
# 3        335985
# 4        335986
#          ...
# 1090    1426307
# 1091    1426309
# 1092    1426310
# 1093    1426311
# 1094    1426312
# Name: id, Length: 1095, dtype: int64

# %%
df.iloc[[2,3,4],9]
# Out:
# 2    Rajasthan Royals
# 3      Mumbai Indians
# 4     Deccan Chargers
# Name: toss_winner, dtype: object

# %%
df.loc[:3,["city","match_type"]]
# Out:
#          city match_type
# 0   Bangalore     League
# 1  Chandigarh     League
# 2       Delhi     League
# 3      Mumbai     League

# %%
df.loc[30:33,["city","match_type"]]
# Out:
#           city match_type
# 30     Chennai     League
# 31   Hyderabad     League
# 32      Jaipur     League
# 33  Chandigarh     League

# %%
df.loc[(df.team1=="Royal Challengers Bangalore")&(df.target_runs>=100)&(df.result_margin>90)]#conditional formatting
# Out:
#            id   season            city        date match_type player_of_match  \
# 0      335982  2007/08       Bangalore  2008-04-18     League     BB McCullum
# 62     392185     2009  Port Elizabeth  2009-04-20     League  M Muralitharan
# 352    598027     2013       Bangalore  2013-04-23     League        CH Gayle
# 496    829785     2015       Bangalore  2015-05-06     League        CH Gayle
# 560    980987     2016       Bangalore  2016-05-14     League  AB de Villiers
# 1009  1359534     2023          Jaipur  2023-05-14     League      WD Parnell
#
#                                venue                        team1  \
# 0              M Chinnaswamy Stadium  Royal Challengers Bangalore
# 62                  St George's Park  Royal Challengers Bangalore
# 352            M Chinnaswamy Stadium  Royal Challengers Bangalore
# 496            M Chinnaswamy Stadium  Royal Challengers Bangalore
# 560            M Chinnaswamy Stadium  Royal Challengers Bangalore
# ...

# %%
df.target_runs.mean()
# Out:
# np.float64(165.68406593406593)

# %%
target_run_mean=df.target_runs.mean()
df.target_runs.map(lambda p:p-target_run_mean)
# Out:
# 0       57.315934
# 1       75.315934
# 2      -35.684066
# 3        0.315934
# 4      -54.684066
#           ...
# 1090    49.315934
# 1091    -5.684066
# 1092     7.315934
# 1093    10.315934
# 1094   -51.684066
# Name: target_runs, Length: 1095, dtype: float64

# %%
def remean_point(row):
    row.target_runs=row.target_runs-target_run_mean
    return row

# %%
df.groupby("team2").target_runs.mean()
# Out:
# team2
# Chennai Super Kings            161.871560
# Deccan Chargers                160.583333
# Delhi Capitals                 176.660000
# Delhi Daredevils               158.789474
# Gujarat Lions                  171.928571
# Gujarat Titans                 172.208333
# Kings XI Punjab                164.448980
# Kochi Tuskers Kerala           142.142857
# Kolkata Knight Riders          161.215385
# Lucknow Super Giants           182.047619
# Mumbai Indians                 167.739130
# Pune Warriors                  162.590909
# Punjab Kings                   181.800000
# Rajasthan Royals               164.907563
# Rising Pune Supergiant         158.444444
# Rising Pune Supergiants        131.571429
# Royal Challengers Bangalore    167.819048
# Royal Challengers Bengaluru    203.166667
# Sunrisers Hyderabad            167.583333
# Name: target_runs, dtype: float64

# %%
df.groupby("team2").team1.count()
# Out:
# team2
# Chennai Super Kings            110
# Deccan Chargers                 36
# Delhi Capitals                  50
# Delhi Daredevils                76
# Gujarat Lions                   14
# Gujarat Titans                  24
# Kings XI Punjab                 98
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders          130
# Lucknow Super Giants            21
# Mumbai Indians                 138
# Pune Warriors                   23
# Punjab Kings                    25
# Rajasthan Royals               120
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Royal Challengers Bangalore    105
# Royal Challengers Bengaluru      6
# Sunrisers Hyderabad             96
# Name: team1, dtype: int64

# %%
df.groupby("team2").target_runs.max()
# Out:
# team2
# Chennai Super Kings            241.0
# Deccan Chargers                199.0
# Delhi Capitals                 273.0
# Delhi Daredevils               212.0
# Gujarat Lions                  249.0
# Gujarat Titans                 225.0
# Kings XI Punjab                246.0
# Kochi Tuskers Kerala           183.0
# Kolkata Knight Riders          236.0
# Lucknow Super Giants           236.0
# Mumbai Indians                 278.0
# Pune Warriors                  264.0
# Punjab Kings                   262.0
# Rajasthan Royals               247.0
# Rising Pune Supergiant         172.0
# Rising Pune Supergiants        192.0
# Royal Challengers Bangalore    236.0
# Royal Challengers Bengaluru    288.0
# Sunrisers Hyderabad            236.0
# Name: target_runs, dtype: float64

# %%
df.groupby("team1").target_runs.min()
# Out:
# team1
# Chennai Super Kings             98.0
# Deccan Chargers                102.0
# Delhi Capitals                 111.0
# Delhi Daredevils                43.0
# Gujarat Lions                  125.0
# Gujarat Titans                  90.0
# Kings XI Punjab                 68.0
# Kochi Tuskers Kerala            98.0
# Kolkata Knight Riders           52.0
# Lucknow Super Giants           154.0
# Mumbai Indians                  68.0
# Pune Warriors                  100.0
# Punjab Kings                   107.0
# Rajasthan Royals                71.0
# Rising Pune Supergiant          74.0
# Rising Pune Supergiants         58.0
# Royal Challengers Bangalore     63.0
# Royal Challengers Bengaluru    173.0
# Sunrisers Hyderabad             48.0
# Name: target_runs, dtype: float64

# %%
df.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
df[0:9:1]#start,stop,step
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
#
#                                         venue                  team1  \
# 0                       M Chinnaswamy Stadium                    RCB
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
# ...

# %%
df[0:10:1]
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                  team1  \
# 0                       M Chinnaswamy Stadium                    RCB
# ...

# %%
df.loc[1]
# Out:
# id                                                     335983
# season                                                2007/08
# city                                               Chandigarh
# date                                               2008-04-19
# match_type                                             League
# player_of_match                                    MEK Hussey
# venue              Punjab Cricket Association Stadium, Mohali
# team1                                         Kings XI Punjab
# team2                                     Chennai Super Kings
# toss_winner                               Chennai Super Kings
# toss_decision                                             bat
# winner                                    Chennai Super Kings
# result                                                   runs
# result_margin                                            33.0
# target_runs                                             241.0
# ...

# %%
df.loc[19,["team1"]]
# Out:
# team1    Chennai Super Kings
# Name: 19, dtype: object

# %%
df.loc[0:9]
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                  team1  \
# 0                       M Chinnaswamy Stadium                    RCB
# ...

# %%
df.loc[0:9,"team1":"result"] # : indicates range of columns
# Out:
#                    team1                  team2          toss_winner  \
# 0                    RCB  Kolkata Knight Riders                  RCB
# 1        Kings XI Punjab    Chennai Super Kings  Chennai Super Kings
# 2       Delhi Daredevils       Rajasthan Royals     Rajasthan Royals
# 3         Mumbai Indians                    RCB       Mumbai Indians
# 4  Kolkata Knight Riders        Deccan Chargers      Deccan Chargers
# 5       Rajasthan Royals        Kings XI Punjab      Kings XI Punjab
# 6        Deccan Chargers       Delhi Daredevils      Deccan Chargers
# 7    Chennai Super Kings         Mumbai Indians       Mumbai Indians
# 8        Deccan Chargers       Rajasthan Royals     Rajasthan Royals
# 9        Kings XI Punjab         Mumbai Indians       Mumbai Indians
#
#   toss_decision                 winner   result
# 0         field  Kolkata Knight Riders     runs
# 1           bat    Chennai Super Kings     runs
# 2           bat       Delhi Daredevils  wickets
# ...

# %%
df.iloc[2,9] #gives the value of 2row and 9 column
# Out:
# 'Rajasthan Royals'

# %%
df.iloc[0:9,0:8]#8 rows (0 to 8) 7 columns(0 to 7)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
#
#                                         venue                  team1
# 0                       M Chinnaswamy Stadium                    RCB
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
# ...

# %%
df.iloc[0:5,2] #2 is the column number
# Out:
# 0     Bangalore
# 1    Chandigarh
# 2         Delhi
# 3        Mumbai
# 4       Kolkata
# Name: city, dtype: object

# %%
df.iloc[[6,4,8]]#6,4,8 are rows
# Out:
#        id   season       city        date match_type player_of_match  \
# 6  335988  2007/08  Hyderabad  2008-04-22     League        V Sehwag
# 4  335986  2007/08    Kolkata  2008-04-20     League       DJ Hussey
# 8  335990  2007/08  Hyderabad  2008-04-24     League       YK Pathan
#
#                                        venue                  team1  \
# 6  Rajiv Gandhi International Stadium, Uppal        Deccan Chargers
# 4                               Eden Gardens  Kolkata Knight Riders
# 8  Rajiv Gandhi International Stadium, Uppal        Deccan Chargers
#
#               team2       toss_winner toss_decision                 winner  \
# 6  Delhi Daredevils   Deccan Chargers           bat       Delhi Daredevils
# 4   Deccan Chargers   Deccan Chargers           bat  Kolkata Knight Riders
# 8  Rajasthan Royals  Rajasthan Royals         field       Rajasthan Royals
#
#     result  result_margin  target_runs  target_overs super_over method  \
# ...

# %%
df.iloc[:,[2,4,5]]#: indicates all values
# Out:
#             city   match_type  player_of_match
# 0      Bangalore       League      BB McCullum
# 1     Chandigarh       League       MEK Hussey
# 2          Delhi       League      MF Maharoof
# 3         Mumbai       League       MV Boucher
# 4        Kolkata       League        DJ Hussey
# ...          ...          ...              ...
# 1090   Hyderabad       League  Abhishek Sharma
# 1091   Ahmedabad  Qualifier 1         MA Starc
# 1092   Ahmedabad   Eliminator         R Ashwin
# 1093     Chennai  Qualifier 2    Shahbaz Ahmed
# 1094     Chennai        Final         MA Starc
#
# [1095 rows x 3 columns]

# %%
df.sort_values("target_runs")#ascending order
# Out:
#            id   season       city        date  match_type  player_of_match  \
# 429    733993     2014      Delhi  2014-05-10      League         DW Steyn
# 633   1082648     2017  Bangalore  2017-05-17  Eliminator  NM Coulter-Nile
# 221    501245     2011    Kolkata  2011-05-07      League    Iqbal Abdulla
# 41     336025  2007/08    Kolkata  2008-05-18      League          M Ntini
# 60     392183     2009  Cape Town  2009-04-19      League       DL Vettori
# ...       ...      ...        ...         ...         ...              ...
# 1031  1422126     2024  Hyderabad  2024-03-27      League  Abhishek Sharma
# 1053  1426268     2024  Bengaluru  2024-04-15      League          TM Head
# 241    501265     2011      Delhi  2011-05-21      League              NaN
# 485    829763     2015  Bangalore  2015-04-29      League              NaN
# 994   1359519     2023    Lucknow  2023-05-03      League              NaN
#
#                                                   venue  \
# ...

# %%
df.duplicated()#no duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1090    False
# 1091    False
# 1092    False
# 1093    False
# 1094    False
# Length: 1095, dtype: bool

# %%
df.loc[df["target_runs"]<50] #data filtering
# Out:
#           id season       city        date  match_type  player_of_match  \
# 429   733993   2014      Delhi  2014-05-10      League         DW Steyn
# 633  1082648   2017  Bangalore  2017-05-17  Eliminator  NM Coulter-Nile
#
#                      venue                team1                  team2  \
# 429       Feroz Shah Kotla     Delhi Daredevils    Sunrisers Hyderabad
# 633  M Chinnaswamy Stadium  Sunrisers Hyderabad  Kolkata Knight Riders
#
#                toss_winner toss_decision                 winner   result  \
# 429    Sunrisers Hyderabad         field    Sunrisers Hyderabad  wickets
# 633  Kolkata Knight Riders         field  Kolkata Knight Riders  wickets
#
#      result_margin  target_runs  target_overs super_over method       umpire1  \
# 429            8.0         43.0           5.0          N    D/L  RM Deshpande
# 633            7.0         48.0           6.0          N    D/L  AK Chaudhary
#
#           umpire2
# 429  BNJ Oxenford
# 633   Nitin Menon

# %%
df.loc[(df["target_runs"]>50)&(df["target_runs"]<80)]
# Out:
#           id   season           city        date match_type  player_of_match  \
# 37    336021  2007/08         Mumbai  2008-05-16     League       SM Pollock
# 41    336025  2007/08        Kolkata  2008-05-18     League          M Ntini
# 60    392183     2009      Cape Town  2009-04-19     League       DL Vettori
# 63    392186     2009         Durban  2009-04-21     League         CH Gayle
# 221   501245     2011        Kolkata  2011-05-07     League    Iqbal Abdulla
# 411   729305     2014      Abu Dhabi  2014-04-26     League         PV Tambe
# 538   980943     2016      Hyderabad  2016-04-26     League         AB Dinda
# 561   980989     2016        Kolkata  2016-05-14     League        YK Pathan
# 565   980997     2016  Visakhapatnam  2016-05-17     League         AB Dinda
# 611  1082626     2017     Chandigarh  2017-04-30     League   Sandeep Sharma
# 630  1082645     2017           Pune  2017-05-14     League       JD Unadkat
# ...

# %%
df.describe()
df["result_margin"].describe()
# Out:
# count    1076.000000
# mean       17.259294
# std        21.787444
# min         1.000000
# 25%         6.000000
# 50%         8.000000
# 75%        20.000000
# max       146.000000
# Name: result_margin, dtype: float64

# %%
df.replace("Royal Challengers Bangalore","RCB",inplace=True)
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                  team1  \
# 0                       M Chinnaswamy Stadium                    RCB
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
# 2                            Feroz Shah Kotla       Delhi Daredevils
# 3                            Wankhede Stadium         Mumbai Indians
# 4                                Eden Gardens  Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  \
# 0  Kolkata Knight Riders                  RCB         field
# ...

# %%
import pandas as pd
df=pd.read_csv("matches.csv")
df.fillna('unknown',inplace=True)
print(df)
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.replace('Bangalore','Bengaluru',inplace=True)
print(df)
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bengaluru  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.replace('Delhi','New Delhi',inplace=True)
print(df)
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bengaluru  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08   New Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...
