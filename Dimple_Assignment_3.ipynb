# %%
import pandas as pd
# Assuming 'Matches' DataFrame is already loaded as shown in the provided code.
Matches= pd.read_csv('/content/matches.csv')
Matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
# Get unique venues and sort them alphabetically
unique_venues = sorted(Matches['venue'].unique())

# Get the total count
venue_count = len(unique_venues)

# Print the results
print("Total number of venues:", venue_count)
print("\nVenues in alphabetical order:")
for venue in unique_venues:
    print(venue)
# Out:
# Total number of venues: 58
#
# Venues in alphabetical order:
# Arun Jaitley Stadium
# Arun Jaitley Stadium, Delhi
# Barabati Stadium
# Barsapara Cricket Stadium, Guwahati
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow
# Brabourne Stadium
# Brabourne Stadium, Mumbai
# Buffalo Park
# De Beers Diamond Oval
# Dr DY Patil Sports Academy
# Dr DY Patil Sports Academy, Mumbai
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam
# Dubai International Cricket Stadium
# Eden Gardens
# Eden Gardens, Kolkata
# Feroz Shah Kotla
# Green Park
# Himachal Pradesh Cricket Association Stadium
# Himachal Pradesh Cricket Association Stadium, Dharamsala
# Holkar Cricket Stadium
# JSCA International Stadium Complex
# Kingsmead
# M Chinnaswamy Stadium
# M Chinnaswamy Stadium, Bengaluru
# M.Chinnaswamy Stadium
# MA Chidambaram Stadium
# MA Chidambaram Stadium, Chepauk
# MA Chidambaram Stadium, Chepauk, Chennai
# ...

# %%
# Group by city and count the number of matches
venue_counts = Matches['venue'].value_counts()

# Create a dictionary to map similar venue names to a single name
venue_mapping = {
    'Arun Jaitley Stadium, Delhi':'Arun Jaitley Stadium',
    'Brabourne Stadium, Mumbai':'Brabourne Stadium',
    'Dr DY Patil Sports Academy, Mumbai':'Dr DY Patil Sports Academy, Navi Mumbai',
    'Dr DY Patil Sports Academy':'Dr DY Patil Sports Academy, Navi Mumbai',
    'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam':'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
    'Himachal Pradesh Cricket Association Stadium, Dharamsala':'Himachal Pradesh Cricket Association Stadium',
    'MA Chidambaram Stadium, Chepauk':'MA Chidambaram Stadium',
    'MA Chidambaram Stadium, Chepauk, Chennai':'MA Chidambaram Stadium',
    'Maharashtra Cricket Association Stadium, Pune':'Maharashtra Cricket Association Stadium',
    'Punjab Cricket Association Stadium, Mohali':'Punjab Cricket Association IS Bindra Stadium',
    'Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh':'Punjab Cricket Association IS Bindra Stadium',
    'Punjab Cricket Association IS Bindra Stadium, Mohali':'Punjab Cricket Association IS Bindra Stadium',
    'Rajiv Gandhi International Stadium, Uppal':'Rajiv Gandhi International Stadium',
    'Rajiv Gandhi International Stadium, Uppal, Hyderabad':'Rajiv Gandhi International Stadium',
    'Sawai Mansingh Stadium, Jaipur':'Sawai Mansingh Stadium',
    'Wankhede Stadium, Mumbai':'Wankhede Stadium',
    'Eden Gardens, Kolkata':'Eden Gardens',
    'M Chinnaswamy Stadium, Bengaluru': 'M.Chinnaswamy Stadium',
    'M Chinnaswamy Stadium':'M.Chinnaswamy Stadium'
  }

# Create a dictionary to map similar cities names to a single name
city_mapping={
    'Bangalore':'Bengaluru'
}

# Replace city names using the mapping
Matches['city'] = Matches['city'].replace(city_mapping)

# replace the city of Dr DY Patil Sports Academy, Navi Mumbai from mumbai to navi mumbai
Matches.loc[Matches['venue'] == 'Dr DY Patil Sports Academy, Navi Mumbai', 'city'] = 'Navi Mumbai'

# Replace venue names using the mapping
Matches['venue'] = Matches['venue'].replace(venue_mapping)

# %%
# calculate the venue counts after combining similar names
updated_venue_counts = Matches['venue'].value_counts()
print(len(updated_venue_counts))
# Out:
# 40

# %%
# calculate venue with  most number of matches within a city
grouped = Matches.groupby(['city','venue']).size().reset_index(name='match_count').sort_values(by=['match_count'], ascending=False)
#grouped
grouped.head(20)
# Out:
#              city                                              venue  \
# 30         Mumbai                                   Wankhede Stadium
# 4       Bengaluru                              M.Chinnaswamy Stadium
# 25        Kolkata                                       Eden Gardens
# 9         Chennai                             MA Chidambaram Stadium
# 18      Hyderabad                 Rajiv Gandhi International Stadium
# 8      Chandigarh       Punjab Cricket Association IS Bindra Stadium
# 12          Delhi                                   Feroz Shah Kotla
# 20         Jaipur                             Sawai Mansingh Stadium
# 34           Pune            Maharashtra Cricket Association Stadium
# 11          Delhi                               Arun Jaitley Stadium
# 0       Abu Dhabi                               Sheikh Zayed Stadium
# 29         Mumbai            Dr DY Patil Sports Academy, Navi Mumbai
# 28         Mumbai                                  Brabourne Stadium
# ...

# %%
# Display the top 20 venues after combining similar names
print(updated_venue_counts.head(20))
#print(updated_venue_counts)
# Out:
# venue
# Wankhede Stadium                                                         118
# M.Chinnaswamy Stadium                                                     94
# Eden Gardens                                                              93
# MA Chidambaram Stadium                                                    85
# Rajiv Gandhi International Stadium                                        77
# Punjab Cricket Association IS Bindra Stadium                              61
# Feroz Shah Kotla                                                          60
# Sawai Mansingh Stadium                                                    57
# Dubai International Cricket Stadium                                       46
# Dr DY Patil Sports Academy, Navi Mumbai                                   37
# Maharashtra Cricket Association Stadium                                   35
# Arun Jaitley Stadium                                                      30
# ...

# %%
# Find A list of the Top 20 Cities where the most number of matches have been played.
top_20_cities = Matches['city'].value_counts().head(20)
top_20_cities
# Out:
# city
# Mumbai           173
# Bengaluru         94
# Kolkata           93
# Delhi             90
# Chennai           85
# Hyderabad         77
# Chandigarh        61
# Jaipur            57
# Pune              51
# Abu Dhabi         37
# Ahmedabad         36
# Visakhapatnam     15
# Durban            15
# Lucknow           14
# Dubai             13
# Dharamsala        13
# Centurion         12
# Sharjah           10
# Rajkot            10
# Navi Mumbai        9
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the bar chart
plt.figure(figsize=(15, 8))  # figure size for better readability
sns.barplot(x=updated_venue_counts.index, y=updated_venue_counts.values) # on x- axis, put the number of matches happened at each venue and on y- axis, put the name of the each venue
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel("Venue") # defining the x- axis as venue
plt.ylabel("Number of Matches") # defining the y- axis as number of matches
plt.title("Number of Matches Played at Each Venue") # defining the title as number of matches at each venue
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show() # show the bar chart

# %%
import folium

# replace with actual venue data
venue_data = {
    'Wankhede Stadium': (18.9388, 72.8258),
    'M. Chinnaswamy Stadium': (12.9797, 77.5997),
    'Eden Gardens': (22.5726, 88.3639),
     'MA Chidambaram Stadium': (13.0625, 80.2790),
     'Rajiv Gandhi International Stadium': (17.4062, 78.5500),
     'Punjab Cricket Association IS Bindra Stadium': (30.6900, 76.7372),
     'Feroz Shah Kotla': (28.6349, 77.2433),
    'Arun Jaitley Stadium':(28.6367, 77.2433),
     'Sawai Mansingh Stadium': (26.8942, 75.8020),
     'Dubai International Cricket Stadium': (25.0463, 55.2204),
     'Dr DY Patil Sports Academy, Navi Mumbai': (19.0435, 73.0267),
     'Maharashtra Cricket Association Stadium': (18.6055, 73.7180),
     'Sheikh Zayed Stadium': (24.4186, 54.6091),
     'Sharjah Cricket Stadium': (25.3360, 55.4209),
     'Brabourne Stadium': (18.9349, 72.8244),
     'Narendra Modi Stadium, Ahmedabad': (23.0546, 72.6043),
     'Subrata Roy Sahara Stadium': (18.5637, 73.8070),
     'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': (17.7298, 83.3115),
     'Kingsmead': (-29.8511, 31.0271),
     'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow': (26.7852, 81.0209),
     'Himachal Pradesh Cricket Association Stadium': (32.1993, 76.3252),
     'Sardar Patel Stadium, Motera': (23.0737, 72.5974),
     'SuperSport Park': (-25.8452, 28.1988),
     'Saurashtra Cricket Association Stadium': (22.3039, 70.8022),
     'Holkar Cricket Stadium': (22.7177, 75.8690),
     'Zayed Cricket Stadium, Abu Dhabi': (24.4181, 54.6089),
     'New Wanderers Stadium': (-26.1313, 28.0567),
     'Barabati Stadium': (20.4727, 85.8586),
     'St Georges Park': (-33.9564, 25.6022),
     'JSCA International Stadium Complex': (23.3441, 85.3218),
     'Newlands': (-33.9730, 18.4682),
     'Shaheed Veer Narayan Singh International Stadium': (21.2506, 81.6296),
     'Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur': (30.7538, 76.7189),
     'Nehru Stadium': (26.1922, 91.7441),
     'Green Park': (26.4787, 80.3500),
     'De Beers Diamond Oval': (-28.7362, 24.7755),
     'Buffalo Park': (-32.9894, 27.9444),
     'Barsapara Cricket Stadium, Guwahati': (26.1342, 91.6341),
     'Vidarbha Cricket Association Stadium, Jamtha': (20.9190, 78.9537),
     'OUTsurance Oval': (-25.7464, 28.2293)
}

# Create a map centered on India
map_center = (20.5937, 78.9629)  # Approximate center of India
m = folium.Map(location=map_center, zoom_start=5)

# Add markers for each venue
for venue, coordinates in venue_data.items():
    folium.Marker(
        location=coordinates,
        popup=venue,
        tooltip=venue
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
